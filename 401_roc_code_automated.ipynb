# %% [markdown]
# # Price Rate of Change indicator ( ROC)

# %%
from mod_my_utils.read_write_data import *
from mod_roc_utils.roc import *

# %%
folder_path = 'data/'
stock_name = 'AAPL'
index_col = 'Date'

# %%
stock_data = get_price_csv(folder_name=folder_path,symbol=stock_name, index_col=index_col)
# Out:
# stock name:  AAPL

# %%
data = stock_data[["Adj. Close"]].copy()
data.columns = ["price"]
data.head()
# Out:
#                 price
# Date
# 2007-12-03  22.986003
# 2007-12-04  23.108091
# 2007-12-05  23.839335
# 2007-12-06  24.411582
# 2007-12-07  24.970258

# %%
# symbols = ["HDFC", 'RELIANCE', 'TCS', 'HINDUNILVR', 'INFY', 'HDFC', 'BHARTIARTL', 'ITC', 'ASIANPAINT', 'NESTLEIND', 'HCLTECH', 'SBI', 'SBIN']

# %%
# symbol = symbols[0]
# data_source = "yahoo"
# # MM/DD/YYYY
# start_date = "1/1/2010"
# end_date = "1/1/2015"
# print(start_date)
# print(end_date)
# print(symbol)
# Out:
# 1/1/2010
# 1/1/2015
# HDFC

# %%
# stock_data = get_price_yahoo(symbol=symbol, data_source=data_source, start_date= start_date, end_date= end_date )
# Out:
# stock name HDFC

# %%
# data = stock_data[["Adj Close"]].copy()
# data.columns = ["price"]
# data.head(5)
# Out:
#                  price
# Date
# 2010-01-04  442.267731
# 2010-01-05  443.772614
# 2010-01-06  445.905945
# 2010-01-07  437.604340
# 2010-01-08  429.980530

# %% [markdown]
# ### ROC related parameters

# %%
period = 5
buy_threshold = -0.1
sell_threshold = 0.1

# %%
roc = get_roc(data[['price']], period)

# %%
signals = get_roc_signal(roc, period, buy_threshold, sell_threshold)

# %%
plot_roc_buy_sell(roc, signals, period, buy_threshold, sell_threshold)
